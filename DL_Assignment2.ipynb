# %%
import tensorflow as tf
#print("Version",tf.__version__)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from keras.models import Sequential
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train =  x_train/255
x_test = x_test/255

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape          ┃      Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)           │ (None, 784)           │            0 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ dense_8 (Dense)               │ (None, 128)           │      100,480 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ dense_9 (Dense)               │ (None, 10)            │        1,290 │
# └───────────────────────────────┴───────────────────────┴──────────────┘
#  Total params: 101,772 (397.55 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
plt.imshow(x_train[0], cmap='gray')
plt.title(f'Label: {y_train[0]}')
#plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(10, 5))

for i in range(100):
    plt.subplot(10, 10, i + 1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')

plt.show()

# %%
import keras
model = Sequential()

# %%
model.add(keras.layers.Flatten(input_shape = (28,28)))

# %%
model.add(keras.layers.Dense(128,activation = 'relu'))

# %%
model.add(keras.layers.Dense(10,activation = 'softmax'))

# %%
model.compile(optimizer = 'sgd', loss= 'sparse_categorical_crossentropy',metrics=["accuracy"])

# %%
history = model.fit(x_train,y_train,validation_data = (x_test,y_test),epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7327 - loss: 1.0037 - val_accuracy: 0.9047 - val_loss: 0.3548
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8993 - loss: 0.3572 - val_accuracy: 0.9170 - val_loss: 0.2985
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9167 - loss: 0.2903 - val_accuracy: 0.9271 - val_loss: 0.2652
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9252 - loss: 0.2698 - val_accuracy: 0.9314 - val_loss: 0.2432
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9321 - loss: 0.2442 - val_accuracy: 0.9357 - val_loss: 0.2258
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9394 - loss: 0.2228 - val_accuracy: 0.9404 - val_loss: 0.2084
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9443 - loss: 0.2022 - val_accuracy: 0.9452 - val_loss: 0.1991
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9450 - loss: 0.1961 - val_accuracy: 0.9467 - val_loss: 0.1857
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9496 - loss: 0.1850 - val_accuracy: 0.9506 - val_loss: 0.1745
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9523 - loss: 0.1735 - val_accuracy: 0.9527 - val_loss: 0.1659

# %%
test_loss,test_acc = model.evaluate(x_test,y_test)
print("LOSS = %.3f" % test_loss)
print("Accuracy = %.3f" % test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9440 - loss: 0.1925
# LOSS = 0.166
# Accuracy = 0.953

# %%
n= random.randint(0,9999)
plt.imshow(x_test[n])
plt.show()

# %%
prediction = model.predict(x_test)
print("Handwritten number in the image is %d" % np.argmax(prediction[n]))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Handwritten number in the image is 6

# %%
# Plot Training Loss and Accuracy

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
#plt.title('Model accuracy')
#plt.ylabel('accuracy')
#plt.xlabel('epoch')
#plt.legend(['Train','Validation'],loc='upper left')
#plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
#plt.title('Model loss')
#plt.ylabel('loss')
#plt.xlabel('epoch')
#plt.legend(['Train','Validation'],loc='upper right')
#plt.show()
